# %%
import pandas as pd

# Fictional rocket launch dataset
data = {
    "Launch Name": ["VX-1 Prometheus", "Nova Aether", "Titanis-3", "Celestia Arrow", "Zephyr Light"],
    "Launch Provider": ["Aestro Aerospace", "Orbital One", "Skyforge", "Eclipse Launch Systems", "AstroCore"],
    "Date": ["2025-03-12", "2025-06-27", "2026-01-15", "2026-08-09", "2027-04-21"],
    "Time (UTC)": ["10:15", "16:45", "03:20", "22:00", "05:30"],
    "Launch Site": ["VBA Launch Complex", "Orion Cape", "Black Horizon Base", "Solport Alpha", "Equatorial Arc"],
    "Longitude": [-72.1023, 142.7789, -10.5521, 89.4423, 56.1134],
    "Latitude": [14.6059, -45.2234, 35.6671, 3.2089, -23.9901],
    "Outcome": ["Success", "Failure", "Partial", "Success", "Success"]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Display the dataset
df
# Out:
#        Launch Name         Launch Provider        Date Time (UTC)  \
# 0  VX-1 Prometheus        Aestro Aerospace  2025-03-12      10:15
# 1      Nova Aether             Orbital One  2025-06-27      16:45
# 2        Titanis-3                Skyforge  2026-01-15      03:20
# 3   Celestia Arrow  Eclipse Launch Systems  2026-08-09      22:00
# 4     Zephyr Light               AstroCore  2027-04-21      05:30
#
#           Launch Site  Longitude  Latitude  Outcome
# 0  VBA Launch Complex   -72.1023   14.6059  Success
# 1          Orion Cape   142.7789  -45.2234  Failure
# 2  Black Horizon Base   -10.5521   35.6671  Partial
# 3       Solport Alpha    89.4423    3.2089  Success
# 4      Equatorial Arc    56.1134  -23.9901  Success
